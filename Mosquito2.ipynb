# %%
open("A2_mosquito_data.csv")
# Out:
# <open file 'A2_mosquito_data.csv', mode 'r' at 0x102d771e0>

# %%
from matplotlib import ticker

fig, ax1 = plt.subplots()
ax1.plot(data['year'], data['mosquitos'])
ax1.set_ylabel('mosquitos', color='b')
plt.ylim(ymin=0)

axes = plt.gca()

ax2 = ax1.twinx()
ax2.plot(data['year'], data['rainfall'],'r')
ax2.set_ylabel('rainfall (mm)', color='r')

plt.ylim(ymin=0)

axes.xaxis.set_major_formatter(ticker.FormatStrFormatter('%d'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-652df2d10c13> in <module>()
#       1 from matplotlib import ticker
#       2
# ----> 3 fig, ax1 = plt.subplots()
#       4 ax1.plot(data['year'], data['mosquitos'])
#       5 ax1.set_ylabel('mosquitos', color='b')
#
# NameError: name 'plt' is not defined

# %%
import pandas
data = pandas.read_csv('A2_mosquito_data.csv')
data
# Out:
#     year  temperature  rainfall  mosquitos
# 0   1960           82       200        180
# 1   1961           70       227        194
# 2   1962           89       231        207
# 3   1963           74       114        121
# 4   1964           78       147        140
# 5   1965           85       151        148
# 6   1966           86       172        162
# 7   1967           75       106        112
# 8   1968           70       276        230
# 9   1969           86       165        162
# 10  1970           83       222        198
# 11  1971           78       297        247
# 12  1972           87       288        248
# 13  1973           76       286        239
# 14  1974           86       231        202
# 15  1975           90       284        243
# 16  1976           76       190        175
# 17  1977           87       257        225
# 18  1978           88       128        133
# 19  1979           87       218        199
# 20  1980           81       206        184
# 21  1981           74       175        160
# 22  1982           85       202        187
# 23  1983           71       130        126
# 24  1984           80       225        200
# 25  1985           72       196        173
# 26  1986           76       261        222
# 27  1987           85       111        121
# 28  1988           83       247        210
# 29  1989           86       137        142
# 30  1990           82       159        152
# 31  1991           77       172        160
# 32  1992           74       280        231
# 33  1993           70       291        238
# 34  1994           77       126        125
# 35  1995           89       191        178
# 36  1996           83       298        248
# 37  1997           80       282        237
# 38  1998           86       219        195
# 39  1999           72       143        134
# 40  2000           79       262        221
# 41  2001           85       189        175
# 42  2002           86       205        186
# 43  2003           72       195        173
# 44  2004           78       148        146
# 45  2005           71       262        219
# 46  2006           88       255        226
# 47  2007           79       262        221
# 48  2008           73       198        176
# 49  2009           86       215        187
# 50  2010           87       127        129

# %%
from matplotlib import ticker
from matplotlib import pyplot as plt

fig, ax1 = plt.subplots()
ax1.plot(data['year'], data['mosquitos'])
ax1.set_ylabel('mosquitos', color='b')
plt.ylim(ymin=0)

axes = plt.gca()

ax2 = ax1.twinx()
ax2.plot(data['year'], data['rainfall'],'r')
ax2.set_ylabel('rainfall (mm)', color='r')

plt.ylim(ymin=0)

axes.xaxis.set_major_formatter(ticker.FormatStrFormatter('%d'))

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
from matplotlib import ticker

fig, ax1 = plt.subplots()
ax1.plot(data['year'], data['mosquitos'])
ax1.set_ylabel('mosquitos', color='b')
plt.ylim(ymin=0)

axes = plt.gca()

ax2 = ax1.twinx()
ax2.plot(data['year'], data['rainfall'],'r')
ax2.set_ylabel('rainfall (mm)', color='r')

plt.ylim(ymin=0)

axes.xaxis.set_major_formatter(ticker.FormatStrFormatter('%d'))

# %%
from matplotlib import ticker
# set the minimum y-value for the y-axes
ystart = 100
from matplotlib import pyplot as plt
fig, ax1 = plt.subplots()
ax1.plot(data['year'], data['mosquitos'])
ax1.set_ylabel('mosquitos', color='b')
plt.ylim(ymin=ystart)

axes = plt.gca()

ax2 = ax1.twinx()
ax2.plot(data['year'], data['rainfall'],'r')
ax2.set_ylabel('rainfall (mm)', color='r')
plt.ylim(ymin=ystart)
plt.xlabel('Year')
plt.show()
axes.xaxis.set_major_formatter(ticker.FormatStrFormatter('%d'))
plt.plot(data['year'],data['mosquitos'])
plt.plot(data['year'],data['rainfall'],'ro-')
plt.ylim(ymin=ystart)
plt.xlabel('Year')
plt.show()

# %%
from matplotlib import pyplot as plt

# %%
plt.subplot?
